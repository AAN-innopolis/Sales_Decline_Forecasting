# %%
import pandas as pd

# %%
data = pd.read_parquet("sales_features.parquet")

# %%
# Set pandas to display all columns
# Set pandas to display ALL rows and columns
pd.set_option('display.max_rows', None)  # Show all rows (for the Series output)
pd.set_option('display.max_columns', None)  # Ensure all columns are visible (if printed as a DataFrame)
pd.set_option('display.width', None)  # Auto-detect terminal width to prevent line-wrapping

# Now print the data types
print(data.dtypes)
# Out:
# date                                 datetime64[ns]
# name                                         object
# address                                      object
# city                                         object
# zipcode                                     float64
# county                                       object
# item_details                                 object
# lon                                         float64
# lat                                         float64
# sale_bottles                                  int64
# sale_bottles_mean                           float64
# sale_bottles_median                         float64
# sale_bottles_std                            float64
# sale_bottles_min                              int64
# sale_bottles_max                              int64
# sale_bottles_skew                           float64
# sale_bottles_sem                            float64
# sale_dollars                                float64
# ...

# %%
data.head(5)
# Out:
#             date                         name       address         city  \
# store
# 2106  2021-04-01  HILLSTREET NEWS AND TOBACCO  2217 COLLEGE  CEDAR FALLS
# 2106  2021-04-08  HILLSTREET NEWS AND TOBACCO  2217 COLLEGE  CEDAR FALLS
# 2106  2021-04-15  HILLSTREET NEWS AND TOBACCO  2217 COLLEGE  CEDAR FALLS
# 2106  2021-04-22  HILLSTREET NEWS AND TOBACCO  2217 COLLEGE  CEDAR FALLS
# 2106  2021-04-29  HILLSTREET NEWS AND TOBACCO  2217 COLLEGE  CEDAR FALLS
#
#        zipcode      county                                       item_details  \
# store
# 2106   50613.0  BLACK HAWK  b'[{"category_name":"IMPORTED CORDIALS & LIQUE...
# 2106   50613.0  BLACK HAWK  b'[{"category_name":"WHISKEY LIQUEUR","im_desc...
# 2106   50613.0  BLACK HAWK  b'[{"category_name":"WHISKEY LIQUEUR","im_desc...
# 2106   50613.0  BLACK HAWK  b'[{"category_name":"STRAIGHT BOURBON WHISKIES...
# 2106   50613.0  BLACK HAWK  b'[{"category_name":"AMERICAN VODKAS","im_desc...
#
# ...
